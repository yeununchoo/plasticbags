# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

save_figures = False
figure_path = "../figures/preprocessing/"
df_init = pd.read_parquet("../data/init.parquet")

# %% [markdown]
# ### Data Cleaning

# %%
df_init
# Out:
#       y  Year  Country  Supermarket                      Time Weather  \
# 0     1  2016    Wales  Tesco Metro     Morning (10.30-11.30)   Sunny
# 1     1  2016    Wales  Tesco Metro     Morning (10.30-11.30)   Sunny
# 2     1  2016    Wales  Tesco Metro     Morning (10.30-11.30)   Sunny
# 3     1  2016    Wales  Tesco Metro     Morning (10.30-11.30)   Sunny
# 4     1  2016    Wales  Tesco Metro     Morning (10.30-11.30)   Sunny
# ...  ..   ...      ...          ...                       ...     ...
# 3759  1  2015  England  Tesco Extra  Saturday Morning (11-12)   Sunny
# 3760  1  2015  England  Tesco Extra  Saturday Morning (11-12)   Sunny
# 3761  1  2015  England  Tesco Extra  Saturday Morning (11-12)   Sunny
# 3762  0  2015  England  Tesco Extra  Saturday Morning (11-12)   Sunny
# 3763  0  2015  England  Tesco Extra  Saturday Morning (11-12)   Sunny
#
#       ObsSize  FemaleN  MaleN                        Gender  \
# 0         1.0      0.0    1.0                          Male
# 1         1.0      0.0    1.0                          Male
# 2         1.0      1.0    0.0                        Female
# 3         2.0      2.0    0.0  Group: Gender not applicable
# 4         1.0      1.0    0.0                        Female
# ...       ...      ...    ...                           ...
# 3759      1.0      1.0    0.0                        Female
# 3760      1.0      1.0    0.0                        Female
# 3761      1.0      1.0    0.0                        Female
# 3762      1.0      1.0    0.0                        Female
# 3763      1.0      1.0    0.0                        Female
#
#                             Age Child
# 0                      36 to 55  None
# 1                      36 to 55  None
# 2                         18-35  None
# 3     Group: Age not applicable  None
# 4                           56+  None
# ...                         ...   ...
# 3759                        56+  None
# 3760                      18-35  None
# 3761                        56+  None
# 3762                        56+  None
# 3763                      18-35  None
#
# [3764 rows x 12 columns]

# %%
year_rename = {"2015":"Y2015",
               "2016":"Y2016"}

df_init["Year"] = df_init["Year"].cat.rename_categories(year_rename)

# %%
time_rename = {"Evening (4.30-5.30)":"Evening",
               "Morning (10.30-11.30)":"Morning",
               "Saturday Morning (11-12)":"SatMorning",
               "Saturday evening (1-2)":"SatEvening"}

df_init["Time"] = df_init["Time"].cat.rename_categories(time_rename)

# %%
df_init
# Out:
#       y   Year  Country  Supermarket        Time Weather  ObsSize  FemaleN  \
# 0     1  Y2016    Wales  Tesco Metro     Morning   Sunny      1.0      0.0
# 1     1  Y2016    Wales  Tesco Metro     Morning   Sunny      1.0      0.0
# 2     1  Y2016    Wales  Tesco Metro     Morning   Sunny      1.0      1.0
# 3     1  Y2016    Wales  Tesco Metro     Morning   Sunny      2.0      2.0
# 4     1  Y2016    Wales  Tesco Metro     Morning   Sunny      1.0      1.0
# ...  ..    ...      ...          ...         ...     ...      ...      ...
# 3759  1  Y2015  England  Tesco Extra  SatMorning   Sunny      1.0      1.0
# 3760  1  Y2015  England  Tesco Extra  SatMorning   Sunny      1.0      1.0
# 3761  1  Y2015  England  Tesco Extra  SatMorning   Sunny      1.0      1.0
# 3762  0  Y2015  England  Tesco Extra  SatMorning   Sunny      1.0      1.0
# 3763  0  Y2015  England  Tesco Extra  SatMorning   Sunny      1.0      1.0
#
#       MaleN                        Gender                        Age Child
# 0       1.0                          Male                   36 to 55  None
# 1       1.0                          Male                   36 to 55  None
# 2       0.0                        Female                      18-35  None
# 3       0.0  Group: Gender not applicable  Group: Age not applicable  None
# 4       0.0                        Female                        56+  None
# ...     ...                           ...                        ...   ...
# 3759    0.0                        Female                        56+  None
# 3760    0.0                        Female                      18-35  None
# 3761    0.0                        Female                        56+  None
# 3762    0.0                        Female                        56+  None
# 3763    0.0                        Female                      18-35  None
#
# [3764 rows x 12 columns]

# %%
df_init["ObsSize"] = df_init["ObsSize"].astype("int")
df_init["FemaleN"] = df_init["FemaleN"].astype("int")
df_init["MaleN"]   = df_init["MaleN"].astype("int")

# %%
df_init["Gender"].replace({"Group: Gender not applicable":np.nan}, inplace = True)
df_init["Age"].replace({"Group: Age not applicable":np.nan}, inplace = True)

age_rename = {"18-35":"Age_g1",
              "36 to 55":"Age_g2",
              "56+":"Age_g3"}

df_init["Age"] = df_init["Age"].cat.rename_categories(age_rename)

# %%
df_init
# Out:
#       y   Year  Country  Supermarket        Time Weather  ObsSize  FemaleN  \
# 0     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 1     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 2     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# 3     1  Y2016    Wales  Tesco Metro     Morning   Sunny        2        2
# 4     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# ...  ..    ...      ...          ...         ...     ...      ...      ...
# 3759  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3760  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3761  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3762  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3763  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
#
#       MaleN  Gender     Age Child
# 0         1    Male  Age_g2  None
# 1         1    Male  Age_g2  None
# 2         0  Female  Age_g1  None
# 3         0     NaN     NaN  None
# 4         0  Female  Age_g3  None
# ...     ...     ...     ...   ...
# 3759      0  Female  Age_g3  None
# 3760      0  Female  Age_g1  None
# 3761      0  Female  Age_g3  None
# 3762      0  Female  Age_g3  None
# 3763      0  Female  Age_g1  None
#
# [3764 rows x 12 columns]

# %%
df_init["Child"].replace({"With child":"Child"}, inplace = True)
df_init["Child"].replace({"None":np.nan}, inplace = True)

# %%
df_init
# Out:
#       y   Year  Country  Supermarket        Time Weather  ObsSize  FemaleN  \
# 0     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 1     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 2     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# 3     1  Y2016    Wales  Tesco Metro     Morning   Sunny        2        2
# 4     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# ...  ..    ...      ...          ...         ...     ...      ...      ...
# 3759  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3760  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3761  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3762  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3763  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
#
#       MaleN  Gender     Age Child
# 0         1    Male  Age_g2   NaN
# 1         1    Male  Age_g2   NaN
# 2         0  Female  Age_g1   NaN
# 3         0     NaN     NaN   NaN
# 4         0  Female  Age_g3   NaN
# ...     ...     ...     ...   ...
# 3759      0  Female  Age_g3   NaN
# 3760      0  Female  Age_g1   NaN
# 3761      0  Female  Age_g3   NaN
# 3762      0  Female  Age_g3   NaN
# 3763      0  Female  Age_g1   NaN
#
# [3764 rows x 12 columns]

# %% [markdown]
# ### Interaction Terms

# %%
df_init["YearCountry"] = df_init["Year"].astype("str") + df_init["Country"].astype("str")
df_init["YearCountry"] = df_init["YearCountry"].astype("category")

# %%
df_init["YearCountryTime"] = df_init["YearCountry"].astype("str") + df_init["Time"].astype("str")
df_init["YearCountryTime"] = df_init["YearCountryTime"].astype("category")

df_init["YearCountrySupermarket"] = df_init["YearCountry"].astype("str") + df_init["Supermarket"].astype("str")
df_init["YearCountrySupermarket"] = df_init["YearCountrySupermarket"].astype("category")
df_init
# Out:
#       y   Year  Country  Supermarket        Time Weather  ObsSize  FemaleN  \
# 0     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 1     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 2     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# 3     1  Y2016    Wales  Tesco Metro     Morning   Sunny        2        2
# 4     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# ...  ..    ...      ...          ...         ...     ...      ...      ...
# 3759  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3760  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3761  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3762  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3763  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
#
#       MaleN  Gender     Age Child   YearCountry         YearCountryTime  \
# 0         1    Male  Age_g2   NaN    Y2016Wales       Y2016WalesMorning
# 1         1    Male  Age_g2   NaN    Y2016Wales       Y2016WalesMorning
# 2         0  Female  Age_g1   NaN    Y2016Wales       Y2016WalesMorning
# 3         0     NaN     NaN   NaN    Y2016Wales       Y2016WalesMorning
# 4         0  Female  Age_g3   NaN    Y2016Wales       Y2016WalesMorning
# ...     ...     ...     ...   ...           ...                     ...
# 3759      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3760      0  Female  Age_g1   NaN  Y2015England  Y2015EnglandSatMorning
# 3761      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3762      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3763      0  Female  Age_g1   NaN  Y2015England  Y2015EnglandSatMorning
#
#        YearCountrySupermarket
# 0       Y2016WalesTesco Metro
# 1       Y2016WalesTesco Metro
# 2       Y2016WalesTesco Metro
# 3       Y2016WalesTesco Metro
# 4       Y2016WalesTesco Metro
# ...                       ...
# 3759  Y2015EnglandTesco Extra
# 3760  Y2015EnglandTesco Extra
# 3761  Y2015EnglandTesco Extra
# 3762  Y2015EnglandTesco Extra
# 3763  Y2015EnglandTesco Extra
#
# [3764 rows x 15 columns]

# %%
df_init["YearCountryGender"] = df_init["YearCountry"].astype("str") + df_init["Gender"].astype("str")
df_init["YearCountryGender"] = df_init["YearCountryGender"].astype("category")
df_init.loc[df_init["Gender"].isna(), "YearCountryGender"] = np.nan
df_init
# Out:
#       y   Year  Country  Supermarket        Time Weather  ObsSize  FemaleN  \
# 0     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 1     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 2     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# 3     1  Y2016    Wales  Tesco Metro     Morning   Sunny        2        2
# 4     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# ...  ..    ...      ...          ...         ...     ...      ...      ...
# 3759  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3760  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3761  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3762  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3763  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
#
#       MaleN  Gender     Age Child   YearCountry         YearCountryTime  \
# 0         1    Male  Age_g2   NaN    Y2016Wales       Y2016WalesMorning
# 1         1    Male  Age_g2   NaN    Y2016Wales       Y2016WalesMorning
# 2         0  Female  Age_g1   NaN    Y2016Wales       Y2016WalesMorning
# 3         0     NaN     NaN   NaN    Y2016Wales       Y2016WalesMorning
# 4         0  Female  Age_g3   NaN    Y2016Wales       Y2016WalesMorning
# ...     ...     ...     ...   ...           ...                     ...
# 3759      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3760      0  Female  Age_g1   NaN  Y2015England  Y2015EnglandSatMorning
# 3761      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3762      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3763      0  Female  Age_g1   NaN  Y2015England  Y2015EnglandSatMorning
#
#        YearCountrySupermarket   YearCountryGender
# 0       Y2016WalesTesco Metro      Y2016WalesMale
# 1       Y2016WalesTesco Metro      Y2016WalesMale
# 2       Y2016WalesTesco Metro    Y2016WalesFemale
# 3       Y2016WalesTesco Metro                 NaN
# 4       Y2016WalesTesco Metro    Y2016WalesFemale
# ...                       ...                 ...
# 3759  Y2015EnglandTesco Extra  Y2015EnglandFemale
# 3760  Y2015EnglandTesco Extra  Y2015EnglandFemale
# 3761  Y2015EnglandTesco Extra  Y2015EnglandFemale
# 3762  Y2015EnglandTesco Extra  Y2015EnglandFemale
# 3763  Y2015EnglandTesco Extra  Y2015EnglandFemale
#
# [3764 rows x 16 columns]

# %%
df_init["YearCountryAge"] = df_init["YearCountry"].astype("str") + df_init["Age"].astype("str")
df_init["YearCountryAge"] = df_init["YearCountryAge"].astype("category")
df_init.loc[df_init["Age"].isna(), "YearCountryAge"] = np.nan
df_init
# Out:
#       y   Year  Country  Supermarket        Time Weather  ObsSize  FemaleN  \
# 0     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 1     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        0
# 2     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# 3     1  Y2016    Wales  Tesco Metro     Morning   Sunny        2        2
# 4     1  Y2016    Wales  Tesco Metro     Morning   Sunny        1        1
# ...  ..    ...      ...          ...         ...     ...      ...      ...
# 3759  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3760  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3761  1  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3762  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
# 3763  0  Y2015  England  Tesco Extra  SatMorning   Sunny        1        1
#
#       MaleN  Gender     Age Child   YearCountry         YearCountryTime  \
# 0         1    Male  Age_g2   NaN    Y2016Wales       Y2016WalesMorning
# 1         1    Male  Age_g2   NaN    Y2016Wales       Y2016WalesMorning
# 2         0  Female  Age_g1   NaN    Y2016Wales       Y2016WalesMorning
# 3         0     NaN     NaN   NaN    Y2016Wales       Y2016WalesMorning
# 4         0  Female  Age_g3   NaN    Y2016Wales       Y2016WalesMorning
# ...     ...     ...     ...   ...           ...                     ...
# 3759      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3760      0  Female  Age_g1   NaN  Y2015England  Y2015EnglandSatMorning
# 3761      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3762      0  Female  Age_g3   NaN  Y2015England  Y2015EnglandSatMorning
# 3763      0  Female  Age_g1   NaN  Y2015England  Y2015EnglandSatMorning
#
#        YearCountrySupermarket   YearCountryGender      YearCountryAge
# 0       Y2016WalesTesco Metro      Y2016WalesMale    Y2016WalesAge_g2
# 1       Y2016WalesTesco Metro      Y2016WalesMale    Y2016WalesAge_g2
# 2       Y2016WalesTesco Metro    Y2016WalesFemale    Y2016WalesAge_g1
# 3       Y2016WalesTesco Metro                 NaN                 NaN
# 4       Y2016WalesTesco Metro    Y2016WalesFemale    Y2016WalesAge_g3
# ...                       ...                 ...                 ...
# 3759  Y2015EnglandTesco Extra  Y2015EnglandFemale  Y2015EnglandAge_g3
# 3760  Y2015EnglandTesco Extra  Y2015EnglandFemale  Y2015EnglandAge_g1
# 3761  Y2015EnglandTesco Extra  Y2015EnglandFemale  Y2015EnglandAge_g3
# 3762  Y2015EnglandTesco Extra  Y2015EnglandFemale  Y2015EnglandAge_g3
# 3763  Y2015EnglandTesco Extra  Y2015EnglandFemale  Y2015EnglandAge_g1
#
# [3764 rows x 17 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df_init.to_parquet("../data/before_split.parquet")

# %% [markdown]
# #### Test, Validation, Training

# %%
y = df_init["y"].to_numpy()
X = df_init.loc[:, df_init.columns != "y"]

random_state = 132

# Train 
X_train, X_other, y_train, y_other = \
    train_test_split(X, y,
                     train_size = 0.8, 
                     random_state = random_state,
                     stratify = y)

# Val and Test
X_val, X_test, y_val, y_test = \
    train_test_split(X_other, y_other,
                     train_size = 0.5,
                     random_state = random_state,
                     stratify = y_other)

# %%
onehot_ftrs = ['Year', 'Country', 'Supermarket', 'Time', 
               'Weather', 'Gender', 'Age', 'Child', 
               'YearCountry', 'YearCountryTime', 'YearCountrySupermarket', 
               'YearCountryGender', 'YearCountryAge']
std_ftrs = ['ObsSize', 'FemaleN', 'MaleN']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(sparse=False,handle_unknown='ignore'), onehot_ftrs),
        ('std', StandardScaler(), std_ftrs)])

clf = Pipeline(steps=[('preprocessor', preprocessor)]) 

X_train_prep = clf.fit_transform(X_train)
X_val_prep = clf.transform(X_val)
X_test_prep = clf.transform(X_test)

# %%
print(X_train_prep.shape)
print(X_val_prep.shape)
print(X_test_prep.shape)
# Out:
# (3011, 85)
# (376, 85)
# (377, 85)

# %%
feature_names = list(preprocessor.named_transformers_["onehot"].get_feature_names(onehot_ftrs)) + \
                     preprocessor.transformers_[1][-1]

# %%
for each in feature_names:
    print(each, end = ", ")
# Out:
# Year_Y2015, Year_Y2016, Country_England, Country_Wales, Supermarket_Asda, Supermarket_Tesco Extra, Supermarket_Tesco Metro, Supermarket_Waitrose, Time_Evening, Time_Morning, Time_SatEvening, Time_SatMorning, Weather_Cloudy, Weather_Rainy, Weather_Sunny, Gender_Female, Gender_Male, Gender_nan, Age_Age_g1, Age_Age_g2, Age_Age_g3, Age_nan, Child_Child, Child_nan, YearCountry_Y2015England, YearCountry_Y2015Wales, YearCountry_Y2016England, YearCountry_Y2016Wales, YearCountryTime_Y2015EnglandEvening, YearCountryTime_Y2015EnglandMorning, YearCountryTime_Y2015EnglandSatEvening, YearCountryTime_Y2015EnglandSatMorning, YearCountryTime_Y2015WalesEvening, YearCountryTime_Y2015WalesMorning, YearCountryTime_Y2015WalesSatEvening, YearCountryTime_Y2015WalesSatMorning, YearCountryTime_Y2016EnglandEvening, YearCountryTime_Y2016EnglandMorning, YearCountryTime_Y2016EnglandSatEvening, YearCountryTime_Y2016EnglandSatMorning, YearCountryTime_Y2016WalesEvening, YearCountryTime_Y2016WalesMorning, YearCountryTime_Y2016WalesSatEvening, YearCountryTime_Y2016WalesSatMorning, YearCountrySupermarket_Y2015EnglandAsda, YearCountrySupermarket_Y2015EnglandTesco Extra, YearCountrySupermarket_Y2015EnglandTesco Metro, YearCountrySupermarket_Y2015EnglandWaitrose, YearCountrySupermarket_Y2015WalesAsda, YearCountrySupermarket_Y2015WalesTesco Extra, YearCountrySupermarket_Y2015WalesTesco Metro, YearCountrySupermarket_Y2015WalesWaitrose, YearCountrySupermarket_Y2016EnglandAsda, YearCountrySupermarket_Y2016EnglandTesco Extra, YearCountrySupermarket_Y2016EnglandTesco Metro, YearCountrySupermarket_Y2016EnglandWaitrose, YearCountrySupermarket_Y2016WalesAsda, YearCountrySupermarket_Y2016WalesTesco Extra, YearCountrySupermarket_Y2016WalesTesco Metro, YearCountrySupermarket_Y2016WalesWaitrose, YearCountryGender_Y2015EnglandFemale, YearCountryGender_Y2015EnglandMale, YearCountryGender_Y2015WalesFemale, YearCountryGender_Y2015WalesMale, YearCountryGender_Y2016EnglandFemale, YearCountryGender_Y2016EnglandMale, YearCountryGender_Y2016WalesFemale, YearCountryGender_Y2016WalesMale, YearCountryGender_nan, YearCountryAge_Y2015EnglandAge_g1, YearCountryAge_Y2015EnglandAge_g2, YearCountryAge_Y2015EnglandAge_g3, YearCountryAge_Y2015WalesAge_g1, YearCountryAge_Y2015WalesAge_g2, YearCountryAge_Y2015WalesAge_g3, YearCountryAge_Y2016EnglandAge_g1, YearCountryAge_Y2016EnglandAge_g2, YearCountryAge_Y2016EnglandAge_g3, YearCountryAge_Y2016WalesAge_g1, YearCountryAge_Y2016WalesAge_g2, YearCountryAge_Y2016WalesAge_g3, YearCountryAge_nan, ObsSize, FemaleN, MaleN,

# %%
df_train = pd.DataFrame(data = X_train_prep, 
                        columns = feature_names)
df_val = pd.DataFrame(data = X_val_prep, 
                      columns = feature_names)
df_test = pd.DataFrame(data = X_test_prep, 
                       columns = feature_names)

df_train["y"] = y_train
df_val["y"] = y_val
df_test["y"] = y_test

# %%
df_train.to_parquet("../data/prep_train.parquet")
df_val.to_parquet("../data/prep_val.parquet")
df_test.to_parquet("../data/prep_test.parquet")

# %% [markdown]
# #### Test, Training

# %%
y = df_init["y"].to_numpy()
X = df_init.loc[:, df_init.columns != "y"]

random_state = 132

# Just Train and Test
X_tt_train, X_tt_test, y_tt_train, y_tt_test = \
    train_test_split(X, y,
                     train_size = 0.9, 
                     random_state = random_state,
                     stratify = y)

# %%
X_tt_train_prep = clf.fit_transform(X_tt_train)
X_tt_test_prep = clf.transform(X_tt_test)

print(X_tt_train_prep.shape)
print(X_tt_test_prep.shape)
# Out:
# (3387, 85)
# (377, 85)

# %%
df_tt_train = pd.DataFrame(data = X_tt_train_prep, 
                           columns = feature_names)
df_tt_test = pd.DataFrame(data = X_tt_test_prep, 
                          columns = feature_names)
df_tt_train["y"] = y_tt_train
df_tt_test["y"] = y_tt_test

# %%
df_tt_train.to_parquet("../data/prep_tt_train.parquet")
df_tt_test.to_parquet("../data/prep_tt_test.parquet")

# %% [markdown]
# #### All

# %%
X_all_prep = clf.fit_transform(X)
df_all = pd.DataFrame(data = X_all_prep, 
                      columns = feature_names)
print(df_all.shape)
df_all["y"] = y
df_all.to_parquet("../data/prep_all.parquet")
# Out:
# (3764, 85)

# %%
df_tt_test.shape
# Out:
# (377, 86)
